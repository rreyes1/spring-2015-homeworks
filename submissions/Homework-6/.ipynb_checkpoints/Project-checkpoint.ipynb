# %%
import json
import pandas as pd
from pprint import pprint
# %matplotlib inline
import pandas as pd
import seaborn as sns
from datetime import datetime
from matplotlib import pyplot as plt
import string
import re
import sklearn.metrics as metrics
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
cas = pd.read_csv('casualties_final.csv')

# %%
df = pd.read_csv('casualties.txt',sep=',')
df.INCDTNO = df.INCDTNO.apply(lambda d: d.strip())
#df = df[df['LONGITUD'] != 0]

# %%
# https://www.gaslampmedia.com/download-zip-code-latitude-longitude-city-state-county-csv/
cities = pd.read_csv('zip_codes_states.csv')
cities = cities.drop(['zip_code'],1)
cities = cities[cities.state != 'PR']
cities = cities.dropna(axis=0)

# %%
#first approach
cas = pd.read_csv('d.txt',sep='\t')
cas = cas.fillna(0)
acceptable_characters = string.letters + string.digits + "-_*."
filter(lambda c: c in acceptable_characters, cas.Type)
cas.Type = cas.Type.apply(lambda row: row[:len(i)-1])
#add_geo(cas,df)

# %%
#checkpoint
cas = pd.read_csv('cas_event_condition_geo.csv')
cas = cas.rename(columns={'Cought': 'Cought on object'})
cas = cas[cas.St.isnull() != True] #DROP HAWAII, #DROP ALASKA
ak = cas[cas.St=='AK']
cas = cas[cas.St != 'AK' ]
cas = cas.drop(cas.columns[[0]],axis=1)
for idx, row in cas.iterrows():
    if row.Month=='January':
        cas.ix[idx, 'Month'] = 1
    elif row.Month=='February':
        cas.ix[idx, 'Month'] = 2
    elif row.Month=='March':
        cas.ix[idx, 'Month'] = 3
    elif row.Month=='April':
        cas.ix[idx, 'Month'] = 4
    elif row.Month=='May':
        cas.ix[idx, 'Month'] = 5
    elif row.Month=='June':
        cas.ix[idx, 'Month'] = 6
    elif row.Month=='July':
        cas.ix[idx, 'Month'] = 7
    elif row.Month=='August':
        cas.ix[idx, 'Month'] = 8
    elif row.Month=='September':
        cas.ix[idx, 'Month'] = 9
    elif row.Month=='October':
        cas.ix[idx, 'Month'] = 10
    elif row.Month=='November':
        cas.ix[idx, 'Month'] = 11
    elif row.Month=='December':
        cas.ix[idx, 'Month'] = 12
# Out:
#         RR Month  Day  TA    Incident               Type  \
# 0      ATK     1    1   3      131150     RR Emp on duty
# 1      ATK     1    1   2      131152         Trespasser
# 2      ATK     1    1   2      131155         Trespasser
# 3      ATK     1    1   3      131393      Nontrespasser
# 4      ATK     1    1   3      131573     RR Emp on duty
# 5     BNSF     1    1   3   SW0114100         Trespasser
# 6      CSX     1    1   3      124326     RR Emp on duty
# 7      CSX     1    1   3      124576      Nontrespasser
# 8     NJTR     1    1   3   201401001         Trespasser
# 9     NJTR     1    1   3   201401002         Trespasser
# 10      NS     1    1   3      108774     RR Emp on duty
# 11    PATH     1    1   3  PSGR011401        Psgr on trn
# 12    UPME     1    1   3   0114CM002     RR Emp on duty
# 13     ATK     1    2   3      131160  Employee off duty
# 14     ATK     1    2   2      131161         Trespasser
# 15     ATK     1    2   2      131161         Trespasser
# 16     ATK     1    2   2      131161     RR Emp on duty
# 17     ATK     1    2   3      131228      Nontrespasser
# 18     ATK     1    2   3      131289        Psgr on trn
# 19     ATK     1    2   3      131368        Psgr on trn
# 20     ATK     1    2   3      131814      Nontrespasser
# 21    BNSF     1    2   3   CA0114001     RR Emp on duty
# 22    BNSF     1    2   3   KS0114001         Contractor
# 23    BNSF     1    2   3   PR0114001     RR Emp on duty
# 24    BNSF     1    2   3   TC0114001     RR Emp on duty
# 25    BSRX     1    2   3       10214     RR Emp on duty
# 26    CRSH     1    2   3      108372     RR Emp on duty
# 27      LI     1    2   3  NT20140120      Nontrespasser
# 28      LI     1    2   3  TP20140103     RR Emp on duty
# 29     LSI     1    2   3       60357     RR Emp on duty
# ...    ...   ...  ...  ..         ...                ...
# 9040    LI    12   30   3  NT20141218      Nontrespasser
# 9041    LI    12   30   3  NT20141219      Nontrespasser
# 9042    LI    12   30   3  NT20141226      Nontrespasser
# 9043    LI    12   30   3  PS20141202     RR Emp on duty
# 9044  NJTR    12   30   3   201501042      Nontrespasser
# 9045  SEPA    12   30   3    Z1412005     RR Emp on duty
# 9046    UP    12   30   2   1214HO055      Nontrespasser
# 9047    UP    12   30   2   1214HO055      Nontrespasser
# 9048    UP    12   30   2   1214HO055      Nontrespasser
# 9049   URR    12   30   3        1409     RR Emp on duty
# 9050   ATK    12   31   3      135724     RR Emp on duty
# 9051   ATK    12   31   3      135819        Psgr on trn
# 9052   ATK    12   31   3      135949      Nontrespasser
# 9053   ATK    12   31   3      135991      Nontrespasser
# 9054  BNSF    12   31   3   SF1214006     RR Emp on duty
# 9055  BNSF    12   31   2   SF1214204         Trespasser
# 9056  BNSF    12   31   2   SF1214204         Trespasser
# 9057    CC    12   31   3      836547         Trespasser
# 9058    CN    12   31   2      836595     RR Emp on duty
# 9059    CN    12   31   2      836595      Nontrespasser
# 9060    CN    12   31   2      836595      Nontrespasser
# 9061   CSX    12   31   2      139414      Nontrespasser
# 9062   CSX    12   31   2      139414      Nontrespasser
# 9063   LSI    12   31   3       63831     RR Emp on duty
# 9064  MNCW    12   31   3         588        Psgr on trn
# 9065  NIRC    12   31   3      MEH118     RR Emp on duty
# 9066  NJTR    12   31   3   201501005         Trespasser
# 9067  NJTR    12   31   3   201502129      Nontrespasser
# 9068    NS    12   31   2      113630      Nontrespasser
# 9069    UP    12   31   3   1214KC018     RR Emp on duty
#
#                             Job                              Condition  \
# 0     Maint. Equipment & Stores                                 Sprain
# 1                             0                       Bruise/contusion
# 2                             0                       Bruise/contusion
# 3                             0                               Fracture
# 4     Maint. Equipment & Stores                                 Sprain
# 5                             0                               Fatality
# 6      Transp, Train and Engine                             Concussion
# 7                             0                             Concussion
# 8                             0  Injury, Crushing/Internal/Unspecified
# 9                             0                               Fatality
# 10     Transp, Train and Engine                                 Sprain
# 11                            0                       Bruise/contusion
# 12       Professional and Admin                                 Sprain
# 13       Professional and Admin                                 Sprain
# 14                            0                       Bruise/contusion
# 15                            0                               Fatality
# 16     Transp, Train and Engine                          Trauma/stress
# 17                            0                                 Sprain
# 18                            0                                 Sprain
# 19                            0                       Bruise/contusion
# 20                            0                             Concussion
# 21     Transp, Train and Engine                               Fracture
# 22    Maint. Equipment & Stores                               Fracture
# 23    MOW & Struct.( No Signal)                       Bruise/contusion
# 24     Transp, Train and Engine                       Bruise/contusion
# 25    Maint. Equipment & Stores                                 Sprain
# 26     Transp, Train and Engine                                 Sprain
# 27                            0                               Fracture
# 28     Transp, Train and Engine                                 Sprain
# 29     Transp, Train and Engine                                 Sprain
# ...                         ...                                    ...
# 9040                          0                                 Sprain
# 9041                          0                           Cut/abrasion
# 9042                          0                               Fracture
# 9043    Transp,NOT Train/Engine                                 Sprain
# 9044                          0                                 Sprain
# 9045   Transp, Train and Engine                       Bruise/contusion
# 9046                          0                       Bruise/contusion
# 9047                          0                       Bruise/contusion
# 9048                          0                       Bruise/contusion
# 9049   Transp, Train and Engine                       Bruise/contusion
# 9050  MOW & Struct.( No Signal)                                 Sprain
# 9051                          0                       Bruise/contusion
# 9052                          0                           Cut/abrasion
# 9053                          0                           Cut/abrasion
# 9054   Transp, Train and Engine                                 Sprain
# 9055                          0  Injury, Crushing/Internal/Unspecified
# 9056                          0                               Fatality
# 9057                          0                           Cut/abrasion
# 9058   Transp, Train and Engine                          Trauma/stress
# 9059                          0                               Fatality
# 9060                          0                               Fatality
# 9061                          0                                 Sprain
# 9062                          0  Injury, Crushing/Internal/Unspecified
# 9063   Transp, Train and Engine                                 Sprain
# 9064                          0                               Fracture
# 9065  Maint. Equipment & Stores                                 Sprain
# 9066                          0                               Fatality
# 9067                          0                                 Sprain
# 9068                          0                                 Sprain
# 9069   Transp, Train and Engine                                 Sprain
#
#                                                   Event  St        County  \
# 0     Repetitive motion - other (describe in narrative)  NY        QUEENS
# 1                         Highway-rail collision/impact  MI       OAKLAND
# 2                         Highway-rail collision/impact  FL  HILLSBOROUGH
# 3                                               Slipped  IL          COOK
# 4     Bodily function/sudden movement, e.g.,sneezing...  CA   LOS ANGELES
# 5                                                Struck  NM        CIBOLA
# 6                                               Slipped  NY        ALBANY
# 7                         Other (describe in narrative)  MD     FREDERICK
# 8                                                Struck  NJ      MONMOUTH
# 9                                                Struck  NJ         UNION
# 10       Collision/impact - auto, truck, bus, van, etc.  MI        MONROE
# 11                                              Slipped  NY      NEW YORK
# 12       Collision/impact - auto, truck, bus, van, etc.  IL          COOK
# 13                                              Slipped  CA     RIVERSIDE
# 14                        Highway-rail collision/impact  NC          WAKE
# 15                        Highway-rail collision/impact  NC          WAKE
# 16                        Highway-rail collision/impact  NC          WAKE
# 17                                         Lost balance  IL          COOK
# 18                                              Slipped  NY          ERIE
# 19                           Sudden/unexpected movement  WA        PIERCE
# 20                                         Lost balance  NJ         ESSEX
# 21                                              Slipped  CA     RIVERSIDE
# 22                           Sudden/unexpected movement  KS       JOHNSON
# 23                                         Overexertion  CO         LOGAN
# 24                                               Struck  WI       DOUGLAS
# 25    Bodily function/sudden movement, e.g.,sneezing...  MO         TANEY
# 26                                         Overexertion  PA      DELAWARE
# 27                                              Slipped  NY        NASSAU
# 28                                         Overexertion  NY       SUFFOLK
# 29                                         Overexertion  MI     MARQUETTE
# ...                                                 ...  ..           ...
# 9040  Bodily function/sudden movement, e.g.,sneezing...  NY      NEW YORK
# 9041                                            Assault  NY      NEW YORK
# 9042                                            Slipped  NY        NASSAU
# 9043  Bodily function/sudden movement, e.g.,sneezing...  NY        QUEENS
# 9044                                            Slipped  NJ        MERCER
# 9045                                             Caught  DE    NEW CASTLE
# 9046                      Highway-rail collision/impact  TX        HARRIS
# 9047                      Highway-rail collision/impact  TX        HARRIS
# 9048                      Highway-rail collision/impact  TX        HARRIS
# 9049                                             Struck  PA     ALLEGHENY
# 9050     Collision/impact - auto, truck, bus, van, etc.  NJ         ESSEX
# 9051                         Sudden/unexpected movement  FL      SEMINOLE
# 9052                                            Slipped  WA         LEWIS
# 9053                                             Struck  CA  CONTRA COSTA
# 9054             Collision - between on track equipment  TN        SHELBY
# 9055                      Highway-rail collision/impact  TN        SHELBY
# 9056                      Highway-rail collision/impact  TN        SHELBY
# 9057                                             Struck  IA      BUCHANAN
# 9058                      Highway-rail collision/impact  MN        ROSEAU
# 9059                      Highway-rail collision/impact  MN        ROSEAU
# 9060                      Highway-rail collision/impact  MN        ROSEAU
# 9061                      Highway-rail collision/impact  KY         CLARK
# 9062                      Highway-rail collision/impact  KY         CLARK
# 9063                                       Overexertion  MI     MARQUETTE
# 9064                                            Slipped  NY   WESTCHESTER
# 9065                                       Overexertion  IL          WILL
# 9066                                             Struck  NJ        BERGEN
# 9067                                            Slipped  NJ         UNION
# 9068                      Highway-rail collision/impact  PA       LUZERNE
# 9069                                       Overexertion  MO       JACKSON
#
#       Age        Long        Lat
# 0      46  -73.830228  40.704546
# 1      19  -83.260000  42.610000
# 2      24  -81.950000  28.040000
# 3       0  -87.746040  41.878251
# 4      48 -118.279269  33.800378
# 5       0 -107.410000  35.040000
# 6      63  -73.928693  42.619626
# 7      25  -77.412389  39.450663
# 8       0  -74.070000  40.340000
# 9      23  -74.380000  40.640000
# 10     46  -83.380000  41.910000
# 11     62  -73.978841  40.767756
# 12     35  -87.890000  41.880000
# 13     58 -116.202401  33.740890
# 14     24  -78.800000  35.770000
# 15     21  -78.800000  35.770000
# 16     59  -78.800000  35.770000
# 17     57  -87.746040  41.878251
# 18     81  -78.790872  42.808838
# 19     43 -122.337446  47.136368
# 20     57  -74.233202  40.780567
# 21     52 -117.560000  33.800000
# 22     30  -94.970000  38.770000
# 23     40 -103.190000  40.630000
# 24     38  -92.110000  46.700000
# 25     27  -93.085757  36.658272
# 26     40  -75.410000  39.810000
# 27      0  -73.614297  40.723548
# 28     53  -72.860683  40.870804
# 29     32  -87.640000  46.430000
# ...   ...         ...        ...
# 9040   49  -73.978841  40.767756
# 9041   25  -73.978841  40.767756
# 9042    0  -73.614297  40.723548
# 9043   42  -73.830228  40.704546
# 9044   49  -74.707781  40.271465
# 9045   55  -75.608671  39.625962
# 9046   26  -95.280000  29.800000
# 9047   48  -95.280000  29.800000
# 9048   49  -95.280000  29.800000
# 9049   54 -107.870000  37.270000
# 9050   58  -74.233202  40.780567
# 9051   82  -81.254097  28.724911
# 9052   76 -122.684384  46.569095
# 9053   25 -122.014351  37.899227
# 9054   42  -90.020000  35.120000
# 9055   52  -89.990000  35.100000
# 9056   53  -89.990000  35.100000
# 9057   32  -91.830000  42.480000
# 9058   46  -95.310000  48.900000
# 9059   35  -95.310000  48.900000
# 9060   33  -95.310000  48.900000
# 9061   38  -84.158752  37.967305
# 9062   21  -84.158752  37.967305
# 9063   43  -87.520000  46.500000
# 9064   35  -73.775226  41.116569
# 9065   25  -87.988459  41.488580
# 9066   52  -74.040000  40.880000
# 9067   38  -74.310508  40.661010
# 9068   47  -75.860000  41.160000
# 9069   46  -94.510000  39.120000
#
# [9019 rows x 14 columns]

# %%
cas.to_csv('casualties_final.csv')

# %%
for idx, row in cas[cas.Lat==0].iterrows():
    co = row.County.title().strip()
    st = row.St.strip()
    if (co=="Washington," and st=='DC'):
        co = 'District Of Columbia'
    co_series = cities[cities.county==co]
    matches = co_series[co_series.state==st]
    cas.ix[idx,'Long'] = matches.longitude.mean()
    cas.ix[idx,'Lat'] = matches.latitude.mean()
cas = cas[cas.Long.isnull() != True]

# %%
for idx, row in cas.iterrows():
    if row.Condition.find('Electric') != -1:
        cas.ix[idx,'Condition'] = 'Electric shock'
    elif row.Condition.find('Heat') != -1:
        cas.ix[idx,'Condition'] = 'Heat'
    elif row.Condition.find('Dislocation') != -1:
        cas.ix[idx,'Condition'] = 'Dislocation'
    elif row.Condition.find('injury') != -1:
        cas.ix[idx,'Condition'] = 'Injury, Crushing/Internal/Unspecified'
        
cas.Event = cas.Event.apply(lambda row:"Caught" if "Caught" in row else row)
cas.Event = cas.Event.apply(lambda row:"Sudden/unexpected movement" if "Sudden" in row else row)
cas.Event = cas.Event.apply(lambda row:"Animal/insect bite/sting" if "Bitten" in row else row)
cas.Event = cas.Event.apply(lambda row:"Electrical Shock" if "Electric" in row else row)
cas.Event = cas.Event.apply(lambda row:"Slipped" if "Slipped" in row else row)
cas.Event = cas.Event.apply(lambda row:"Struck" if "Struck" in row else row)
cas.Event = cas.Event.apply(lambda row:"Assault" if "Assault" in row or "Stab" in row
                            or "Shot" in row else row)
#print cas.Event.value_counts()[cas.Event.value_counts() > 10]

# %%
def add_geo(subframe, largerframe):
    for idx, row in subframe.iterrows():
        i = row.Incident
        for jdx, rowj in largerframe.iterrows():
            if i==rowj.INCDTNO:
                subframe.ix[idx,'Long'] = rowj.LONGITUD
                subframe.ix[idx,'Lat'] = rowj.LATITUDE
                break
    return subframe

# %%
cols = cas.Condition.value_counts()[cas.Condition.value_counts()>2].index
conditions = pd.DataFrame(index=cas.RR.unique(), columns= cols)
for rail, rail_data in cas.groupby("RR"):
    conditions.ix[rail,cols] = rail_data.Condition.value_counts()[cols]
conditions=conditions.fillna(0)

victims = pd.DataFrame(index=cas.RR.unique(), columns= cas.Type.unique())
for rail, rail_data in cas.groupby("RR"):
    victims.ix[rail,rail_data.Type.unique()] = rail_data.Type.value_counts()
victims=victims.fillna(0)
#victims.head()

#electric shock is a condition, electrical is a cause/event
events = pd.DataFrame(index=cas.RR.unique(), columns= cas.Event.unique())
for rail, rail_data in cas.groupby("RR"):
    events.ix[rail,rail_data.Event.unique()] = rail_data.Event.value_counts()
    events.ix[rail,'Count'] = rail_data.RR.count()
events = events.fillna(0)

for rail, rail_data in cas.groupby('RR'):
    events.ix[rail,'Condition'] = rail_data.Condition.value_counts().index[0]
    conditions.ix[rail,'Event'] = rail_data.Event.value_counts().index[0]
conditions.Event = conditions.Event.apply(lambda row: row[0:10])

events_top = events.sort(columns='Count',ascending=False)[0:40]
events = events.drop(['Count'],axis=1)
events_top = events_top.drop(['Count'],axis=1)

trains = pd.concat([victims, events],axis=1)
trains_top = trains.ix[events_top.index]

# %% [markdown]
# Here we start exploring the values:

# %%
train ='ATK'
#tdf = cas[cas.RR==train]
tdf = cas

# %%
types = tdf.Type.value_counts()
types.plot(kind='barh',figsize=(10, 5),fontsize=20).set_title('Types of Victims',fontsize=20);

# %%
cons = tdf.Condition.value_counts().ix[0:10]
cons.plot(kind='barh',figsize=(10, 5), fontsize=20).set_title('Condition of Victims',fontsize=20);

# %%
events = tdf.Event.value_counts().ix[0:10]
events.plot(kind='barh',figsize=(10, 5),fontsize=20).set_title('Event causing casuality',fontsize=20);

# %% [markdown]
# train vs condition of victim
# Train vs Type of Victim
# Trains vs event that caused the accident

# %%
cas = cas.fillna(0)
X= cas.Long.values
Y= cas.Lat.values
X_scaler = StandardScaler(with_std=True)
scaled_X = X_scaler.fit_transform(X)
Y_scaler = StandardScaler(with_std=True)
scaled_Y = Y_scaler.fit_transform(Y)
cas['SCALED_LONG'] = scaled_X
cas['SCALED_LAT'] = scaled_Y

# %%
cas.plot(kind='scatter',x='SCALED_LONG',y='SCALED_LAT')

# %%
fig, axes = plt.subplots(3,4,figsize=(15,10))

for idx in range(1,13):
    i = idx // 4
    j = idx % 4
    c = cas[cas.Month==idx]
#    print idx, c.RR.count()
    x = c.SCALED_LONG
    y = c.SCALED_LAT
    axes[i-1][j].scatter(x,y, c="slategray", alpha=0.4, linewidths=0.3)
    #plt.scatter(subX_test, y_test)
    axes[i-1][j].set_xlabel('Long')
    axes[i-1][j].set_ylabel('lat');

# %%
def evaluate_clustering(X, max_k):
    inertia = []
    inertia.append(0)
    for k in range(1, max_k + 1):
        kmeans = KMeans(init='k-means++', n_clusters=k, n_init=5)
        kmeans.fit_predict(X)
        inertia.append(kmeans.inertia_)
    return inertia

# %%
from numpy import hstack
from numpy import atleast_2d, where

data = hstack((atleast_2d(scaled_X).T, atleast_2d(scaled_Y).T))
inertia_k = evaluate_clustering(data, 15)

# %%
ax = plt.subplot(111)
ax.plot(inertia_k)
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
ax.set_xlim(1, len(inertia_k))
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
labels = kmeans.fit_predict(data)
m = pd.DataFrame()
with sns.axes_style("white"):
    ax = plt.subplot(111)
    # Define a color palette
    cmap = sns.color_palette(n_colors=6)
    cmap.extend(sns.hls_palette(n_colors=6, h=0.7, l=0.4, s=0.8))
    # Iterate over the different clustering labels, find the points
    # that belong to that cluster and plot them with the same color
    for i, label in enumerate(set(labels)):
        point_indices = where(labels == label)[0]
        point_indices = point_indices.tolist()
        ax.scatter(X[point_indices], Y[point_indices], s=70, 
                    alpha=1, c=cmap[i], marker='+')
        a = pd.DataFrame([X[point_indices], Y[point_indices]])
        a = a.T
        a['Label'] = i
        m = pd.concat([m,a],axis=0)
m.to_csv('map1.txt')

# %%
#who they were
#whether they died or not
#what happened
#when did it happen

# %%
cas['STRUCK'] = cas.Event.apply(lambda row: 1 if row == "Struck" else 0)
cas['SLIP'] = cas.Event.apply(lambda row: 1 if row == "Slipped" else 0)
cas['HIGHWAY'] = cas.Event.apply(lambda row: 1 if row == "Highway-rail collision/impact" else 0)
cas['FATAL'] = cas.Condition.apply(lambda row: 1 if "Fatal" in row else 0)
cas['SPRAIN'] = cas.Condition.apply(lambda row: 1 if "Sprain" in row else 0)
cas['EMPLOYEE'] = cas.Type.apply(lambda row: 1 if "Emp" in row else 0)
cas['PASSENGER'] = cas.Type.apply(lambda row: 1 if "Psgr" in row else 0)
cas['SCALED_MONTH'] = MinMaxScaler(copy=True).fit_transform(cas.Month *1.)

# %%
#factors=['STRUCK','SLIP','HIGHWAY','FATAL','SPRAIN','EMPLOYEE','PASSENGER','Month']
#variables = ['STRUCK','SLIP','HIGHWAY','FATAL','SPRAIN','EMPLOYEE','PASSENGER']

factors=['FATAL','EMPLOYEE','SCALED_MONTH']
variables = ['FATAL','EMPLOYEE','SCALED_MONTH']
for i in ['SCALED_LONG','SCALED_LAT','Long','Lat']:
    variables.append(i)
dataset = cas[variables]

# %%
inertia_k = evaluate_clustering(dataset[factors], 10)

# %%
plt.rcParams['figure.figsize'] = (10,10)
ax = plt.subplot(111)
ax.plot(inertia_k)
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
ax.set_xlim(1, len(inertia_k))
# Out:
# (1, 11)

# %%
from sklearn.cluster import k_means
n_clusters = 5
centroids, labels, inertia = k_means (dataset[factors],
                                    n_clusters =n_clusters,
                                    random_state = 150)
centroids = pd.DataFrame(centroids,columns=(factors))

print centroids
# Out:
#           FATAL      EMPLOYEE  SCALED_MONTH
# 0  8.771930e-04  1.000000e+00      0.217145
# 1  2.831069e-15  2.053913e-14      0.224438
# 2  1.000000e+00  6.172840e-03      0.525477
# 3  1.403837e-03  1.000000e+00      0.756668
# 4  2.164935e-15  2.003953e-14      0.758962

# %%
cmap = sns.cubehelix_palette(start=0.3, light=0.9, as_cmap=True)
titles=factors
plt.rcParams['figure.figsize'] = (14,7 * n_clusters)

for i, label in enumerate(set(labels)):
    point_indices = where(labels == label)[0]
    point_indices = point_indices.tolist()
    cluster = dataset.iloc[point_indices]
    with sns.axes_style("white"):
        ax = plt.subplot(n_clusters, 2, 2 * i + 1)
#        ax = draw_boston(ax)
        ax.hexbin(cluster.Long,
                      cluster.Lat,
                      bins='log',
                      gridsize=35,
                      cmap=cmap, alpha=0.5, mincnt=1)
        ax.set_title("Cluster %d records" % (i + 1))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    with sns.axes_style('darkgrid'):
        ax = plt.subplot(n_clusters, 2, 2 * i + 2)
        sns.violinplot(cluster[factors],
                       ax=ax,
                       names=titles)
        ax.set_title("Cluster %d description" % (i + 1))
        
# restore the default figure size
plt.rcParams['figure.figsize'] = (15,12)

# %%
sample = cas.RR.value_counts()[cas.RR.value_counts()>5].index.tolist()
column_names = set(events.columns.values.tolist())
column_names.remove('Condition')
numerical = events[list(column_names)].loc[sample]
distance_matrix = squareform(pdist(numerical, metric='cosine'))
fig = plt.subplots(1,1,figsize=(8,10))
Z = linkage(distance_matrix, method='complete')
R = dendrogram(Z,
               labels=events.Condition.loc[sample].values.tolist(),
               orientation='right',
               truncate_mode='mtica',
               p=10,
               distance_sort='descending')

# %%
from numpy.random import RandomState
# Keep the columns that refer only to ingredients
column_names = set(events.columns.values.tolist())
column_names.remove('Condition')
numerical = events
numerical = numerical[list(column_names)]
print len(numerical)
# Compute the similarity matrix between the different cuisines
distance_matrix = squareform(pdist(numerical.values, metric='cosine'))
# Read this matrix as a Dataframe, with the column names and the index 
# set to be the name of the cuisines.
similarities = pd.DataFrame(distance_matrix, 
                            columns=list(numerical.index), 
                            index=list(numerical.index))
cg = sns.clustermap(similarities, method="complete", figsize=(10,10), 
                    xticklabels=False, metric='cosine', col_cluster=True,
                    cmap=sns.cubehelix_palette(reverse=True, light=1, as_cmap=True))

# %%
events_top = events.sort(columns='Slipped',ascending=False)[0:30]

# %%
from numpy.random import RandomState
# Keep the columns that refer only to ingredients
#events_top = events_top.ix[0:30]
column_names = set(events_top.columns.values.tolist())
column_names.remove('Condition')
numerical = events_top
numerical = numerical[list(column_names)]
# Compute the similarity matrix between the different cuisines
distance_matrix = squareform(pdist(numerical.values, metric='cosine'))
similarities = pd.DataFrame(distance_matrix, 
                            columns=list(numerical.index), 
                            index=list(numerical.index))
cg = sns.clustermap(similarities, method="complete", figsize=(10,10), 
                    xticklabels=False, metric='cosine', col_cluster=True,
                    cmap=sns.cubehelix_palette(reverse=True, light=1, as_cmap=True))

# %%
from numpy.random import RandomState
# Keep the columns that refer only to ingredients
column_names = set(trains_top.columns.values.tolist())
column_names.remove('Condition')
numerical = trains_top
numerical = numerical[list(column_names)]
print len(numerical)
# Compute the similarity matrix between the different cuisines
distance_matrix = squareform(pdist(numerical.values, metric='cosine'))
# Read this matrix as a Dataframe, with the column names and the index 
# set to be the name of the cuisines.
similarities = pd.DataFrame(distance_matrix, 
                            columns=list(numerical.index), 
                            index=list(numerical.index))
cg = sns.clustermap(similarities, method="complete", figsize=(10,10), 
                    xticklabels=False, metric='cosine', col_cluster=True,
                    cmap=sns.cubehelix_palette(reverse=True, light=1, as_cmap=True))
# Out:
# 40

# %% [markdown]
# What I'm trying to show in the abov code is that the major railroad companies have similarities in terms of the types of accidents that have
#
# The central cluster contains
# SEPA - Philadelphia,
# MBTA - Boston,
# LI- Long Island,
# NJTR - New Jersey Transit,
# PATH - New Jersey - NYC
# ATK - Amtrak
# MNCW - Metronorth - NYC-> CT
# MACZ - Maryland -> DC
# NIRC (northern illinoi)
# UPMC - Chicago and outlying areas

# %%
TRE DALLAS
FEC FLORIDA
PCDX PITTSBURGH
SCAX SoCal

GTW GRAND TRUNK MI, IL
KCS = KANSAS CITY
WC WISCONSIN

# %%
#cas from the website to excel
#cas.to_csv('cas_event')
#cas.to_csv('cas_event_condition.csv')
#cas.to_csv('cas_event_condition_geo.csv')
#cas.to_csv('cas_event_condition_geo_noAK.csv')
